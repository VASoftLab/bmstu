# %% [markdown]
# ### Titanic

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic_train.csv");
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Удаляем лишние столбцы (незначимые данные)
df.drop(["PassengerId", "Name"], axis = 1, inplace = True)
df.head(3)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
#
#   Cabin Embarked
# 0   NaN        S
# 1   C85        C
# 2   NaN        S

# %%
df.drop(["Ticket", "Cabin", "Embarked"], axis = 1, inplace = True)
df.head(3)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250

# %%
df.shape
# Out:
# (891, 7)

# %%
# Удаляем NA данные
df = df.dropna()
df.shape
# Out:
# (714, 7)

# %%
y = df["Survived"]
X = df.iloc[:, 1:]

# %%
X
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare
# 0         3    male  22.0      1      0   7.2500
# 1         1  female  38.0      1      0  71.2833
# 2         3  female  26.0      0      0   7.9250
# 3         1  female  35.0      1      0  53.1000
# 4         3    male  35.0      0      0   8.0500
# ..      ...     ...   ...    ...    ...      ...
# 885       3  female  39.0      0      5  29.1250
# 886       2    male  27.0      0      0  13.0000
# 887       1  female  19.0      0      0  30.0000
# 889       1    male  26.0      0      0  30.0000
# 890       3    male  32.0      0      0   7.7500
#
# [714 rows x 6 columns]

# %%
y = np.array(y)
X = np.array(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8)

# %%
X_train.shape
# Out:
# (571, 6)

# %%
# Строки нельзя использовать для работы классификатора
# Поэтому переделаем датафрейм
df = df.replace({"male": 1, "female": 0})
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare
# 0         0       3    1  22.0      1      0   7.2500
# 1         1       1    0  38.0      1      0  71.2833
# 2         1       3    0  26.0      0      0   7.9250
# 3         1       1    0  35.0      1      0  53.1000
# 4         0       3    1  35.0      0      0   8.0500

# %%
y = df["Survived"]
X = df.iloc[:, 1:]
y = np.array(y)
X = np.array(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8)

# %%
X
# Out:
# array([[ 3.    ,  1.    , 22.    ,  1.    ,  0.    ,  7.25  ],
#        [ 1.    ,  0.    , 38.    ,  1.    ,  0.    , 71.2833],
#        [ 3.    ,  0.    , 26.    ,  0.    ,  0.    ,  7.925 ],
#        ...,
#        [ 1.    ,  0.    , 19.    ,  0.    ,  0.    , 30.    ],
#        [ 1.    ,  1.    , 26.    ,  0.    ,  0.    , 30.    ],
#        [ 3.    ,  1.    , 32.    ,  0.    ,  0.    ,  7.75  ]])

# %%
# Выполняем поиск наилучшего классификатора
np.random.seed(42)
# Параметры можно варьировать автоматически
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
             'ccp_alpha': [0.1, 0.01, 0.001],
             'max_depth': [2, 3],
             'criterion': ['gini', 'entropy']}

dec_tree = DecisionTreeClassifier()
# Заполняем таблицу для перебора параметров
grid_search = GridSearchCV(estimator = dec_tree,
                           param_grid = param_grid,
                           cv = 5, verbose = True)
grid_search.fit(X_train, y_train)
best_dec_tree = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\VA\anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\VA\anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\VA\anaconda3\lib\site-packages\sklearn\tree\_classes.py:298: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# ...

# %%
# Анализ точности
score = accuracy_score(y_test, best_dec_tree.predict(X_test))
print(f"Accuracy: {score}")
plt.figure(figsize = (12, 12), dpi = 300)
tree.plot_tree(best_dec_tree, feature_names = df.columns[1:])
# Out:
# Accuracy: 0.7342657342657343
# [Text(0.5, 0.875, 'Sex <= 0.5\nentropy = 0.978\nsamples = 571\nvalue = [335, 236]'),
#  Text(0.25, 0.625, 'SibSp <= 2.5\nentropy = 0.761\nsamples = 213\nvalue = [47, 166]'),
#  Text(0.125, 0.375, 'Fare <= 40.633\nentropy = 0.72\nsamples = 201\nvalue = [40, 161]'),
#  Text(0.0625, 0.125, 'entropy = 0.869\nsamples = 138\nvalue = [40, 98]'),
#  Text(0.1875, 0.125, 'entropy = 0.0\nsamples = 63\nvalue = [0, 63]'),
#  Text(0.375, 0.375, 'SibSp <= 4.5\nentropy = 0.98\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.3125, 0.125, 'entropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.4375, 0.125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.625, 'Parch <= 0.5\nentropy = 0.713\nsamples = 358\nvalue = [288, 70]'),
#  Text(0.625, 0.375, 'Age <= 24.5\nentropy = 0.649\nsamples = 289\nvalue = [241, 48]'),
#  Text(0.5625, 0.125, 'entropy = 0.41\nsamples = 85\nvalue = [78, 7]'),
# ...
