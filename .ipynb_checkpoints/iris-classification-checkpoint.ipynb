# %% [markdown]
# ### Тестовое задание "Классификация цветков ириса"
# <br><b>Выполнил:</b> <i>Альчаков В.В. гр. AD11872/3<i>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle

from keras.utils import np_utils
from keras.utils.np_utils import to_categorical

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

import tf2onnx
# import keras2onnx
import onnx

from matplotlib import pyplot
# %matplotlib inline

# %% [markdown]
# ### Загрузка тестового набора

# %%
iris = pd.read_csv("iris.csv")
iris = iris.drop(['Id'], axis = 1)
iris = shuffle(iris)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 116            6.5           3.0            5.5           1.8   Iris-virginica
# 18             5.7           3.8            1.7           0.3      Iris-setosa
# 85             6.0           3.4            4.5           1.6  Iris-versicolor
# 96             5.7           2.9            4.2           1.3  Iris-versicolor
# 63             6.1           2.9            4.7           1.4  Iris-versicolor
# ..             ...           ...            ...           ...              ...
# 41             4.5           2.3            1.3           0.3      Iris-setosa
# 136            6.3           3.4            5.6           2.4   Iris-virginica
# 59             5.2           2.7            3.9           1.4  Iris-versicolor
# 25             5.0           3.0            1.6           0.2      Iris-setosa
# 21             5.1           3.7            1.5           0.4      Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Кодирование признаков

# %%
lb = LabelEncoder()
lb.fit_transform(iris['Species'])
# Out:
# array([2, 0, 1, 1, 1, 0, 0, 0, 1, 2, 0, 0, 2, 2, 0, 2, 0, 2, 1, 2, 2, 2,
#        1, 2, 2, 2, 2, 2, 0, 0, 1, 0, 0, 2, 2, 2, 2, 2, 2, 1, 0, 0, 2, 0,
#        1, 1, 2, 1, 2, 1, 2, 0, 1, 2, 1, 1, 0, 0, 1, 1, 2, 2, 1, 1, 2, 1,
#        0, 1, 0, 2, 2, 0, 2, 0, 1, 2, 0, 1, 2, 0, 2, 0, 2, 1, 1, 1, 0, 0,
#        1, 2, 0, 0, 2, 2, 1, 2, 1, 1, 1, 0, 2, 1, 1, 0, 1, 0, 1, 0, 2, 2,
#        0, 2, 1, 0, 2, 0, 0, 1, 1, 2, 1, 0, 2, 0, 2, 0, 1, 1, 2, 0, 1, 0,
#        0, 0, 1, 1, 0, 1, 0, 1, 2, 1, 0, 1, 1, 0, 2, 1, 0, 0])

# %%
iris['Species'] = lb.fit_transform(iris['Species'])
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 116            6.5           3.0            5.5           1.8        2
# 18             5.7           3.8            1.7           0.3        0
# 85             6.0           3.4            4.5           1.6        1
# 96             5.7           2.9            4.2           1.3        1
# 63             6.1           2.9            4.7           1.4        1
# ..             ...           ...            ...           ...      ...
# 41             4.5           2.3            1.3           0.3        0
# 136            6.3           3.4            5.6           2.4        2
# 59             5.2           2.7            3.9           1.4        1
# 25             5.0           3.0            1.6           0.2        0
# 21             5.1           3.7            1.5           0.4        0
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Разбивка данных на тестовую и проверочную выборки

# %%
X = iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].values
y = pd.get_dummies(iris['Species']).values # One hot encoding
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100, shuffle = True)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120, 3)
# (30, 4)
# (30, 3)

# %% [markdown]
# ### Нормализация данных

# %%
normalizer = tf.keras.layers.Normalization(axis = -1)
normalizer.adapt(np.array(X))

# %% [markdown]
# ### Определяем структуру нейронной сети

# %%
#model = tf.keras.Sequential([
#    tf.keras.layers.Dense(10, activation='relu'),
#    tf.keras.layers.Dense(10, activation='relu'),
#    tf.keras.layers.Dense(3, activation='softmax')
#])

n_features = X.shape[1] # Размерность X
model = Sequential()
#model.add(normalizer)
model.add(Dense(10, activation = 'relu', input_shape = (n_features, )))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(3, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
#model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 50, verbose = 1, validation_data = (X_test, y_test))
# Out:
# Epoch 1/100
# 3/3 [==============================] - 1s
- val_accuracy: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 147ms/step - loss: 0.7899 - accuracy: 0.8583 - val_loss: 0.7869 - val_accuracy: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 173ms/step - loss: 0.7837 - accuracy: 0.8583 - val_loss: 0.7785 - val_accuracy: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 136ms/step - loss: 0.7779 - accuracy: 0.8583 - val_loss: 0.7699 - val_accuracy: 0.9667
# Epoch 55/100
# 3/3 [==============================] - 0s 137ms/step - loss: 0.7714 - accuracy: 0.8583 - val_loss: 0.7622 - val_accuracy: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.7649 - accuracy: 0.8583 - val_loss: 0.7543 - val_accuracy: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 133ms/step - loss: 0.7587 - accuracy: 0.8667 - val_loss: 0.7464 - val_accuracy: 0.9333
# Epoch 58/100
# 3/3 [==============================] - 0s 134ms/step - loss: 0.7520 - accuracy: 0.8667 - val_loss: 0.7399 - val_accuracy: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 149ms/step - loss: 0.7454 - accuracy: 0.8750 - val_loss: 0.7327 - val_accuracy: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.7389 - accuracy: 0.8750 - val_loss: 0.7258 - val_accuracy: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.7327 - accuracy: 0.8750 - val_loss: 0.7186 - val_accuracy: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.7257 - accuracy: 0.8750 - val_loss: 0.7100 - val_accuracy: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.7188 - accuracy: 0.8750 - val_loss: 0.7009 - val_accuracy: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 173ms/step - loss: 0.7117 - accuracy: 0.8833 - val_loss: 0.6933 - val_accuracy: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 139ms/step - loss: 0.7049 - accuracy: 0.8750 - val_loss: 0.6857 - val_accuracy: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 151ms/step - loss: 0.6981 - accuracy: 0.8750 - val_loss: 0.6771 - val_accuracy: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 133ms/step - loss: 0.6915 - accuracy: 0.8750 - val_loss: 0.6690 - val_accuracy: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 152ms/step - loss: 0.6846 - accuracy: 0.8750 - val_loss: 0.6600 - val_accuracy: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.6778 - accuracy: 0.8833 - val_loss: 0.6520 - val_accuracy: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 172ms/step - loss: 0.6712 - accuracy: 0.8833 - val_loss: 0.6443 - val_accuracy: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 170ms/step - loss: 0.6637 - accuracy: 0.8833 - val_loss: 0.6383 - val_accuracy: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 174ms/step - loss: 0.6574 - accuracy: 0.9000 - val_loss: 0.6328 - val_accuracy: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 166ms/step - loss: 0.6519 - accuracy: 0.9250 - val_loss: 0.6264 - val_accuracy: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 199ms/step - loss: 0.6452 - accuracy: 0.9167 - val_loss: 0.6170 - val_accuracy: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 144ms/step - loss: 0.6372 - accuracy: 0.9250 - val_loss: 0.6091 - val_accuracy: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 142ms/step - loss: 0.6306 - accuracy: 0.9167 - val_loss: 0.6009 - val_accuracy: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 180ms/step - loss: 0.6239 - accuracy: 0.9167 - val_loss: 0.5937 - val_accuracy: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.6172 - accuracy: 0.9250 - val_loss: 0.5853 - val_accuracy: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 171ms/step - loss: 0.6105 - accuracy: 0.9167 - val_loss: 0.5762 - val_accuracy: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 176ms/step - loss: 0.6038 - accuracy: 0.9000 - val_loss: 0.5676 - val_accuracy: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.5972 - accuracy: 0.9000 - val_loss: 0.5588 - val_accuracy: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 145ms/step - loss: 0.5912 - accuracy: 0.9000 - val_loss: 0.5502 - val_accuracy: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.5844 - accuracy: 0.9000 - val_loss: 0.5431 - val_accuracy: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 156ms/step - loss: 0.5777 - accuracy: 0.9167 - val_loss: 0.5350 - val_accuracy: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 129ms/step - loss: 0.5710 - accuracy: 0.9250 - val_loss: 0.5263 - val_accuracy: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 136ms/step - loss: 0.5650 - accuracy: 0.9000 - val_loss: 0.5178 - val_accuracy: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 182ms/step - loss: 0.5591 - accuracy: 0.9000 - val_loss: 0.5104 - val_accuracy: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 168ms/step - loss: 0.5525 - accuracy: 0.9000 - val_loss: 0.5042 - val_accuracy: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 175ms/step - loss: 0.5462 - accuracy: 0.9250 - val_loss: 0.4984 - val_accuracy: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 215ms/step - loss: 0.5400 - accuracy: 0.9250 - val_loss: 0.4929 - val_accuracy: 1.0000

# %%
loss, accuracy = model.evaluate(X_test, y_test, verbose = 0)
print('Test loss:', loss)
print('Test accuracy:', accuracy)

# %%
y_pred = model.predict(X_test)
y_pred

# %%
actual = np.argmax(y_test, axis = 1)
predicted = np.argmax(y_pred, axis = 1)
print(f"Actual: {actual}")
print(f"Pred-d: {predicted}")

# %%
#onnx_model = keras2onnx.convert_keras(model, model.name)
#onnx.save_model(onnx_model, "iris.onnx")
# Экспорт модели
onnx_model, _ = tf2onnx.convert.from_keras(model)
onnx.save(onnx_model, "model\iris.onnx")
